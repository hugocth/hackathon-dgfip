# %% [markdown]
# # Data exploration
#
# In this notebook, we extract the data from the DGFiP's API and we do preliminary data exploration.

# %%
# Imports and setups

import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import requests
from utils import API_to_df

print("Setup done!")
# Out:
# Setup done!

# %%
# Coordonnées des structures DGFIP


gdf = API_to_df("coordonnees-des-structures-dgfip","geojson")
gdf.head()
# Out:
#   nomenclature_interne  ...                   geometry
# 0           Buralistes  ...   POINT (0.90323 48.54165)
# 1           Buralistes  ...  POINT (-0.01168 48.74623)
# 2           Buralistes  ...  POINT (-0.02499 48.74104)
# 3           Buralistes  ...   POINT (0.45681 48.85833)
# 4           Buralistes  ...   POINT (0.54536 48.52050)
#
# [5 rows x 24 columns]
