# %% [markdown]
# # Data exploration
#
# In this notebook, we extract the data from the DGFiP's API and we do preliminary data exploration.

# %%
# Imports and setups

import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from utils import *

print("Setup done!")
# Out:
# Setup done!

# %%
# Coordonnées des structures DGFIP

gdf = API_to_df("coordonnees-des-structures-dgfip", "geojson")
gdf.head()
# Out:
#   nomenclature_interne type_de_service libelle_du_service  \
# 0           Buralistes      Buralistes         Buralistes
# 1           Buralistes      Buralistes         Buralistes
# 2           Buralistes      Buralistes         Buralistes
# 3           Buralistes      Buralistes         Buralistes
# 4           Buralistes      Buralistes         Buralistes
#
#         nom_du_service departement                        adresse    bp  \
# 0  LA BONNE FRANQUETTE          61              1 RUE DES AZALEES  None
# 1           LA ROTONDE          61               RUE JEANNE D ARC  None
# 2         LE LONGCHAMP          61           50 BOULEVARD  CARNOT  None
# 3       L' ETOILE D'OR          61                  6  GRANDE RUE  None
# 4           LA CIVETTE          61  12 PLACE DU GENERAL DE GAULLE  None
#
#   code_postal              commune code_commune  ...  \
# 0       61290  LONGNY LES VILLAGES        61230  ...
# 1       61200             ARGENTAN        61006  ...
# 2       61200             ARGENTAN        61006  ...
# 3       61550    LA FERTE EN OUCHE        61167  ...
# 4       61400   MORTAGNE AU PERCHE        61293  ...
#
#                                     type_de_demarche telephone_1 telephone_2  \
# 0  > Paiement des impôts en espèces et CB dans la...        None        None
# 1  > Paiement des impôts en espèces et CB dans la...        None        None
# 2  > Paiement des impôts en espèces et CB dans la...        None        None
# 3  > Paiement des impôts en espèces et CB dans la...        None        None
# 4  > Paiement des impôts en espèces et CB dans la...        None        None
#
#   dep_name reg_code   reg_name current_code             com_name  \
# 0     Orne       28  Normandie        61230  Longny les Villages
# 1     Orne       28  Normandie        61006             Argentan
# 2     Orne       28  Normandie        61006             Argentan
# 3     Orne       28  Normandie        61167    La Ferté-en-Ouche
# 4     Orne       28  Normandie        61293   Mortagne-au-Perche
#
#   dep_code_de_geocodage                   geometry
# 0                    61   POINT (0.90323 48.54165)
# 1                    61  POINT (-0.01168 48.74623)
# 2                    61  POINT (-0.02499 48.74104)
# 3                    61   POINT (0.45681 48.85833)
# 4                    61   POINT (0.54536 48.52050)
#
# [5 rows x 24 columns]

# %%
print(values(gdf,["type_de_demarche"]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\hugoc\Documents\Code\hackathon-dgfip\data-exploration.ipynb Cell 4' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/hugoc/Documents/Code/hackathon-dgfip/data-exploration.ipynb#ch0000003?line=0'>1</a> print(values(gdf,["type_de_demarche"]))
#
# NameError: name 'values' is not defined
